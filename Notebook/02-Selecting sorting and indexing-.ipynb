# %%
# import data
import pandas as pd
df = pd.read_csv('C:/Users/there/notebook/csv files/world happiness dataset/2018.csv')

#rename country or region to country
df.rename(columns = {'Country or region':'Country'}, inplace=True)
df
# Out:
#      Overall rank                   Country  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
# filter result base on a column
df[df['Overall rank'] > 20]
# Out:
#      Overall rank                   Country  Score  GDP per capita  \
# 20             21            Czech Republic  6.711           1.233
# 21             22                     Malta  6.627           1.270
# 22             23                    France  6.489           1.293
# 23             24                    Mexico  6.488           1.038
# 24             25                     Chile  6.476           1.131
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 20            1.489                    0.854                         0.543
# ...

# %%
#filter result base on if value are in a column in result
countries = ['Yemen','Nigeria']

df[df['Country'].isin(countries)]
# Out:
#      Overall rank  Country  Score  GDP per capita  Social support  \
# 90             91  Nigeria  5.155           0.689           1.172
# 151           152    Yemen  3.355           0.442           1.073
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 90                     0.048                         0.462       0.201
# 151                    0.343                         0.244       0.083
#
#      Perceptions of corruption
# 90                       0.032
# 151                      0.064

# %%
#filter result set if a particular string value is in a column
df[df['Country'].str.contains('Niger')]
# Out:
#      Overall rank  Country  Score  GDP per capita  Social support  \
# 90             91  Nigeria  5.155           0.689           1.172
# 133           134    Niger  4.166           0.131           0.867
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 90                     0.048                         0.462       0.201
# 133                    0.221                         0.390       0.175
#
#      Perceptions of corruption
# 90                       0.032
# 133                      0.099

# %%
# filter using the filter method
df.filter(items = [0, 1], axis=0)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social support  \
# 0             1  Finland  7.632           1.305           1.592
# 1             2   Norway  7.594           1.456           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340

# %%
df.filter(like = 'Cou', axis=1)
# Out:
#                       Country
# 0                     Finland
# 1                      Norway
# 2                     Denmark
# 3                     Iceland
# 4                 Switzerland
# ..                        ...
# 151                     Yemen
# 152                  Tanzania
# 153               South Sudan
# 154  Central African Republic
# 155                   Burundi
#
# [156 rows x 1 columns]

# %%
#sorting columns
df[df['Overall rank'] < 10].sort_values(by=['Overall rank'], ascending= True )

# %%
# to reset index
df.reset_index(inplace=True)

# %%
# Set index
df.set_index('Country', inplace=True)

# %%
# view a row using it location
#df.loc['Finland']
df

# %%
# view a row using it index location
df.iloc[0]

# %%
# multi indexing
df.set_index(['Country','Score'], inplace=True)

# %%
# sorting index
df.sort_index(ascending=[False,False])
