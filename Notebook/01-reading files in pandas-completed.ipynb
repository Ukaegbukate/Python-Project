# %%
# import pandas
import pandas as pd

# we will be reading a csv file
df = pd.read_csv('C:/Users/there/notebook/csv files/world happiness dataset/2019.csv')

# %% [markdown]
# you can also import other file formats
#
# ![image.png](attachment:image.png)

# %%
# show imported file
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# 5               6               Switzerland  7.480           1.452
# 6               7                    Sweden  7.343           1.387
# 7               8               New Zealand  7.307           1.303
# 8               9                    Canada  7.278           1.365
# 9              10                   Austria  7.246           1.376
# 10             11                 Australia  7.228           1.372
# 11             12                Costa Rica  7.167           1.034
# 12             13                    Israel  7.139           1.276
# ...

# %%
# show only a specific number of the top rows
df.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
# show only a specific number of the top rows
df.tail(10)
# Out:
#      Overall rank         Country or region  ...  Generosity  \
# 146           147                     Haiti  ...       0.419
# 147           148                  Botswana  ...       0.025
# 148           149                     Syria  ...       0.331
# 149           150                    Malawi  ...       0.218
# 150           151                     Yemen  ...       0.108
# 151           152                    Rwanda  ...       0.217
# 152           153                  Tanzania  ...       0.276
# 153           154               Afghanistan  ...       0.158
# 154           155  Central African Republic  ...       0.235
# 155           156               South Sudan  ...       0.202
#
#      Perceptions of corruption
# 146                      0.110
# 147                      0.100
# 148                      0.141
# 149                      0.089
# 150                      0.077
# 151                      0.411
# 152                      0.147
# 153                      0.025
# ...

# %%
# to display all rows of a dataframe at once
pd.set_option('display.max.rows',200)
pd.set_option('display.max.columns', 40)

# %%
# to get info about a dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# to get a quick statistical analysis of you dataset
df.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
# to get the no of rows and columns of our data
df.shape
# Out:
# (156, 9)

# %%
# retrieve a single column or row
df['Score']
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
# 5      7.480
# 6      7.343
# 7      7.307
# 8      7.278
# 9      7.246
# 10     7.228
# 11     7.167
# 12     7.139
# 13     7.090
# 14     7.054
# 15     7.021
# 16     6.985
# 17     6.923
# 18     6.892
# 19     6.852
# 20     6.825
# 21     6.726
# 22     6.595
# 23     6.592
# 24     6.446
# 25     6.444
# 26     6.436
# 27     6.375
# 28     6.374
# 29     6.354
# 30     6.321
# 31     6.300
# 32     6.293
# 33     6.262
# 34     6.253
# 35     6.223
# 36     6.199
# 37     6.198
# 38     6.192
# 39     6.182
# 40     6.174
# 41     6.149
# 42     6.125
# 43     6.118
# 44     6.105
# 45     6.100
# 46     6.086
# 47     6.070
# 48     6.046
# 49     6.028
# 50     6.021
# 51     6.008
# 52     5.940
# 53     5.895
# 54     5.893
# 55     5.890
# 56     5.888
# 57     5.886
# 58     5.860
# 59     5.809
# 60     5.779
# 61     5.758
# 62     5.743
# 63     5.718
# 64     5.697
# 65     5.693
# ...

# %%
# retrieve a single column or row
df[['Score', 'Generosity']]
# Out:
#      Score  Generosity
# 0    7.769       0.153
# 1    7.600       0.252
# 2    7.554       0.271
# 3    7.494       0.354
# 4    7.488       0.322
# 5    7.480       0.263
# 6    7.343       0.267
# 7    7.307       0.330
# 8    7.278       0.285
# 9    7.246       0.244
# 10   7.228       0.332
# 11   7.167       0.144
# 12   7.139       0.261
# 13   7.090       0.194
# 14   7.054       0.348
# 15   7.021       0.298
# 16   6.985       0.261
# 17   6.923       0.160
# 18   6.892       0.280
# 19   6.852       0.046
# 20   6.825       0.262
# 21   6.726       0.375
# 22   6.595       0.074
# 23   6.592       0.111
# 24   6.446       0.242
# 25   6.444       0.187
# 26   6.436       0.175
# 27   6.375       0.080
# 28   6.374       0.220
# 29   6.354       0.153
# 30   6.321       0.109
# 31   6.300       0.099
# 32   6.293       0.127
# 33   6.262       0.271
# 34   6.253       0.093
# 35   6.223       0.158
# 36   6.199       0.255
# 37   6.198       0.121
# 38   6.192       0.185
# ...

# %%
# export data from notebook
df.to_csv('C:/Users/there/notebook/csv files/exported_files.csv')
