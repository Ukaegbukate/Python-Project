# %%
# import data
import pandas as pd
df = pd.read_csv('C:/Users/there/notebook/csv files/world happiness dataset/2018.csv')

# %%
# filter result base on a column
df
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
# 5                    0.878                         0.638       0.333
# 6                    0.896                         0.653       0.321
# 7                    0.876                         0.669       0.365
# 8                    0.913                         0.659       0.285
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357
# 5                      0.295
# 6                      0.291
# 7                      0.389
# 8                      0.383

# %%
#filter result base on if value are in a column in result
needed_country = ['Canada', 'Sweden','Nigeria']

df[df['Country or region'].isin(needed_country)]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 6              7            Canada  7.328           1.330           1.532
# 8              9            Sweden  7.314           1.355           1.501
# 90            91           Nigeria  5.155           0.689           1.172
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 6                     0.896                         0.653       0.321
# 8                     0.913                         0.659       0.285
# 90                    0.048                         0.462       0.201
#
#     Perceptions of corruption
# 6                       0.291
# 8                       0.383
# 90                      0.032

# %%
#filter result set if a particular string value is in a column
df[df['Country or region'].str.contains('United')]
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 10            11        United Kingdom  7.190           1.244           1.433
# 17            18         United States  6.886           1.398           1.471
# 19            20  United Arab Emirates  6.774           2.096           0.776
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 10                    0.888                         0.464       0.262
# 17                    0.819                         0.547       0.291
# 19                    0.670                         0.284       0.186
#
#     Perceptions of corruption
# 10                      0.082
# 17                      0.133
# 19                        NaN

# %%
# filter using the filter method
#rename country or region to country
df.rename(columns = {'Country or region': 'Country'}, inplace=True)
#set the index to country
df.set_index('Country', inplace = True)

# %%
df
df.filter(items = ['Nigeria', 'Finland'], axis=0)
# Out:
#          Overall rank  Score  GDP per capita  Social support  \
# Country
# Nigeria            91  5.155           0.689           1.172
# Finland             1  7.632           1.305           1.592
#
#          Healthy life expectancy  Freedom to make life choices  Generosity  \
# Country
# Nigeria                    0.048                         0.462       0.201
# Finland                    0.874                         0.681       0.202
#
#          Perceptions of corruption
# Country
# Nigeria                      0.032
# Finland                      0.393

# %%
df.filter(like = 'Nigeria', axis=0)
# Out:
#          Overall rank  Score  GDP per capita  Social support  \
# Country
# Nigeria            91  5.155           0.689           1.172
#
#          Healthy life expectancy  Freedom to make life choices  Generosity  \
# Country
# Nigeria                    0.048                         0.462       0.201
#
#          Perceptions of corruption
# Country
# Nigeria                      0.032

# %%
#sorting columns
df[df['Overall rank'] <= 10].sort_values(by=['Overall rank'], ascending=False )
# Out:
#              Overall rank  Score  GDP per capita  Social support  \
# Country
# Australia              10  7.272           1.340           1.573
# Sweden                  9  7.314           1.355           1.501
# New Zealand             8  7.324           1.268           1.601
# Canada                  7  7.328           1.330           1.532
# Netherlands             6  7.441           1.361           1.488
# Switzerland             5  7.487           1.420           1.549
# Iceland                 4  7.495           1.343           1.644
# Denmark                 3  7.555           1.351           1.590
# Norway                  2  7.594           1.456           1.582
# Finland                 1  7.632           1.305           1.592
#
#              Healthy life expectancy  Freedom to make life choices  \
# Country
# Australia                      0.910                         0.647
# Sweden                         0.913                         0.659
# New Zealand                    0.876                         0.669
# Canada                         0.896                         0.653
# Netherlands                    0.878                         0.638
# Switzerland                    0.927                         0.660
# Iceland                        0.914                         0.677
# Denmark                        0.868                         0.683
# Norway                         0.861                         0.686
# Finland                        0.874                         0.681
#
#              Generosity  Perceptions of corruption
# Country
# Australia         0.361                      0.302
# Sweden            0.285                      0.383
# New Zealand       0.365                      0.389
# Canada            0.321                      0.291
# Netherlands       0.333                      0.295
# Switzerland       0.256                      0.357
# Iceland           0.353                      0.138
# Denmark           0.284                      0.408
# Norway            0.286                      0.340
# Finland           0.202                      0.393

# %%
# to reset index
df.reset_index(inplace = True)
df.set_index('Country', inplace=True)

# %%
df.loc['Finland']
# Out:
# Overall rank                    1.000
# Score                           7.632
# GDP per capita                  1.305
# Social support                  1.592
# Healthy life expectancy         0.874
# Freedom to make life choices    0.681
# Generosity                      0.202
# Perceptions of corruption       0.393
# Name: Finland, dtype: float64

# %%
df.iloc[0]
# Out:
# Overall rank                    1.000
# Score                           7.632
# GDP per capita                  1.305
# Social support                  1.592
# Healthy life expectancy         0.874
# Freedom to make life choices    0.681
# Generosity                      0.202
# Perceptions of corruption       0.393
# Name: Finland, dtype: float64

# %%
# multi indexing
df.reset_index(inplace=True)
df.set_index(['Country','Score'], inplace=True)

# %%
df
# Out:
#                                 Overall rank  GDP per capita  Social support  \
# Country                  Score
# Finland                  7.632             1           1.305           1.592
# Norway                   7.594             2           1.456           1.582
# Denmark                  7.555             3           1.351           1.590
# Iceland                  7.495             4           1.343           1.644
# Switzerland              7.487             5           1.420           1.549
# ...                                      ...             ...             ...
# Yemen                    3.355           152           0.442           1.073
# Tanzania                 3.303           153           0.455           0.991
# South Sudan              3.254           154           0.337           0.608
# Central African Republic 3.083           155           0.024           0.000
# Burundi                  2.905           156           0.091           0.627
#
#                                 Healthy life expectancy  \
# Country                  Score
# Finland                  7.632                    0.874
# Norway                   7.594                    0.861
# Denmark                  7.555                    0.868
# Iceland                  7.495                    0.914
# Switzerland              7.487                    0.927
# ...                                                 ...
# Yemen                    3.355                    0.343
# Tanzania                 3.303                    0.381
# South Sudan              3.254                    0.177
# Central African Republic 3.083                    0.010
# Burundi                  2.905                    0.145
#
#                                 Freedom to make life choices  Generosity  \
# Country                  Score
# Finland                  7.632                         0.681       0.202
# Norway                   7.594                         0.686       0.286
# Denmark                  7.555                         0.683       0.284
# Iceland                  7.495                         0.677       0.353
# Switzerland              7.487                         0.660       0.256
# ...                                                      ...         ...
# Yemen                    3.355                         0.244       0.083
# Tanzania                 3.303                         0.481       0.270
# South Sudan              3.254                         0.112       0.224
# Central African Republic 3.083                         0.305       0.218
# Burundi                  2.905                         0.065       0.149
#
#                                 Perceptions of corruption
# Country                  Score
# Finland                  7.632                      0.393
# Norway                   7.594                      0.340
# Denmark                  7.555                      0.408
# Iceland                  7.495                      0.138
# Switzerland              7.487                      0.357
# ...                                                   ...
# Yemen                    3.355                      0.064
# Tanzania                 3.303                      0.097
# South Sudan              3.254                      0.106
# Central African Republic 3.083                      0.038
# Burundi                  2.905                      0.076
#
# [156 rows x 7 columns]

# %%
# sorting index
df.sort_index(ascending=False)
# Out:
#                    Overall rank  GDP per capita  Social support  \
# Country     Score
# Zimbabwe    3.692           144           0.357           1.094
# Zambia      4.377           125           0.562           1.047
# Yemen       3.355           152           0.442           1.073
# Vietnam     5.103            95           0.715           1.365
# Venezuela   4.806           102           0.996           1.469
# ...                         ...             ...             ...
# Argentina   6.388            29           1.073           1.468
# Angola      3.795           142           0.730           1.125
# Algeria     5.295            84           0.979           1.154
# Albania     4.586           112           0.916           0.817
# Afghanistan 3.632           145           0.332           0.537
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country     Score
# Zimbabwe    3.692                    0.248                         0.406
# Zambia      4.377                    0.295                         0.503
# Yemen       3.355                    0.343                         0.244
# Vietnam     5.103                    0.702                         0.618
# Venezuela   4.806                    0.657                         0.133
# ...                                    ...                           ...
# Argentina   6.388                    0.744                         0.570
# Angola      3.795                    0.269                         0.000
# Algeria     5.295                    0.687                         0.077
# Albania     4.586                    0.790                         0.419
# Afghanistan 3.632                    0.255                         0.085
#
#                    Generosity  Perceptions of corruption
# Country     Score
# Zimbabwe    3.692       0.132                      0.099
# Zambia      4.377       0.221                      0.082
# Yemen       3.355       0.083                      0.064
# Vietnam     5.103       0.177                      0.079
# Venezuela   4.806       0.056                      0.052
# ...                       ...                        ...
# Argentina   6.388       0.062                      0.054
# Angola      3.795       0.079                      0.061
# Algeria     5.295       0.055                      0.135
# Albania     4.586       0.149                      0.032
# Afghanistan 3.632       0.191                      0.036
#
# [156 rows x 7 columns]
